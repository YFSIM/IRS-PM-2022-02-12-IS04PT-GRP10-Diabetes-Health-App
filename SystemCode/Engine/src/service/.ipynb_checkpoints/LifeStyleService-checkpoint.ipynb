# %%
import sys
import os
import pandas as pd

import pickle
import json
from collections import namedtuple
from json import JSONEncoder
import RecipeService
from RecipeService import *
import ActivityService
from ActivityService import *


def dt_lsmodel():
    module_path = os.path.abspath(os.path.join('../..'))
    filepath = module_path + '/' + 'model/' + 'decision_tree_classifier.pkl'
    print(filepath)


    decision_tree_model_pkl = open(filepath, 'rb')
    decision_tree_model = pickle.load(decision_tree_model_pkl)
    return decision_tree_model

def knn_lsmodel():
    module_path = os.path.abspath(os.path.join('../..'))
    filepath = module_path + '/' + 'model/' + 'knn_classifier.pkl'
    print(filepath)


    knn_model_pkl = open(filepath, 'rb')
    knn_model = pickle.load(knn_model_pkl)
    return knn_model
    
def predictBMI(input,model_type):
    model = dt_lsmodel()
    if model_type == 'knn':
        model = knn_lsmodel()
    predict_value = model.predict(input)
    return predict_value

def test():
    df_predict = pd.read_csv("bmi_test.csv")
    print(predictBMI(df_predict,"knn"))

def customHealthDecoder(healthDict):
    return namedtuple('X', healthDict.keys())(*healthDict.values())

def physicalActivity(currentpa,target,currentMET,minofexercise,currentNoOfExercise,activity):
    if currentpa < target:

        if (currentNoOfExercise < 5):
            pa_add_5 = 5 * minofexercise * currentMET

            if (pa_add_5 >= target):
                physical_activity_advice = 'Please increase your number of exercise to 5x a week'
            elif (pa_add_5 < target and minofexercise < 30):

                pa_add_5_30 = 5 * 30 * currentMET

                if (pa_add_5_30 < target):
                    paDataList = json.loads(find_motion_activity(activity))

                    for index in range(len(paDataList)):

                        if paDataList[index]['met'] > currentMET:
                            countPA = 5 * 30 * paDataList[index]['met']
                            if (countPA >= target):
                                physical_activity_advice = 'Please increase your number of exercise to 5x a week and each 30 minutes and try to do ' + paDataList[index]['specificmotion'] 
                                break
                    if physical_activity_advice == '':
                        physical_activity_advice = 'Please increase your number of exercise to 5x a week and each 30 minutes and try to do moderate type of exercise'                                
                else:
                    physical_activity_advice = 'Please increase your number of exercise to 5x a week and each 30 minutes'
            elif (pa_add_5 < target and minofexercise > 30):
                paDataList = json.loads(find_motion_activity(activity))
                for index in range(len(paDataList)):
                    if paDataList[index]['met'] > currentMET:
                        countPA = 5 * 30 * paDataList[index]['met']
                        if (countPA >= target):
                            physical_activity_advice = 'Please increase your number of exercise to 5x a week and each 30 minutes and try to do ' + paDataList[index]['specificmotion'] 
                            break
                if physical_activity_advice == '':
                    physical_activity_advice = 'Please increase your number of exercise to 5x a week and each 30 minutes and try to do moderate type of exercise'                                
        elif (minofexercise < 30):  
            pa_add_30 = currentNoOfExercise * 30 * currentMET
            if (pa_add_30 < target):
                paDataList = json.loads(find_motion_activity(activity))
                for index in range(len(paDataList)):
                    if paDataList[index]['met'] > currentMET:
                        countPA = currentNoOfExercise * 30 * paDataList[index]['met']
                        if (countPA >= target):
                            physical_activity_advice = 'Please increase your exercise time to 30 minutes and try to do ' + paDataList[index]['specificmotion'] 
                            break
                if physical_activity_advice == '':
                    physical_activity_advice = 'Please increase your number of exercise to 5x a week and each 30 minutes and try to do moderate type of exercise'                                
            else:
                physical_activity_advice = 'Please increase your exercise time to 30 minutes'
        elif(minofexercise >= 30 and currentNoOfExercise >= 5):
            paDataList = json.loads(find_motion_activity(activity))
            for index in range(len(paDataList)):
                if paDataList[index]['met'] > currentMET:
                    countPA = currentNoOfExercise * 30 * paDataList[index]['met']
                    if (countPA >= target):
                        physical_activity_advice = 'Please increase your exercise time to 30 minutes and try to do ' + paDataList[index]['specificmotion'] 
                        break
            if physical_activity_advice == '':
                physical_activity_advice = 'Please increase your number of exercise to 5x a week and each 30 minutes and try to do moderate type of exercise'              
        else:
            physical_activity_advice = 'Please increase your exercise activity'
    return physical_activity_advice

def predictHealthRisk(request_data):
    
    physical_activity_advice = ''
    b_meal_advice = ''
    l_meal_advice = ''
    d_meal_advice = ''
    try:

        # Parse JSON into an object with attributes corresponding to dict keys.
        healthData = json.loads(request_data, object_hook=customHealthDecoder)
        bmi_actual = healthData.weight / ((healthData.height/100) * (healthData.height/100))

        paData = json.loads(find_met(healthData.activity, healthData.motion), object_hook=customHealthDecoder)
        pa = healthData.noofexerciseaweek * healthData.minofexercise * paData[0].METs

        jsonbreakFast = json.loads(calculate_ingredient(healthData.breakfast))

        df_breakfast = pd.json_normalize(jsonbreakFast)
        df_breakfast['pa'] = pa
        df_breakfast['age_x'] = healthData.age
        df_breakfast['mealtime']=1

        bmi_breakfast= predictBMI(df_breakfast,'knn')[0]

        #------------------------------------------------------------
        jsonLunch = json.loads(calculate_ingredient(healthData.lunch))

        df_lunch = pd.json_normalize(jsonLunch)
        df_lunch['pa'] = pa
        df_lunch['age_x'] = healthData.age
        df_lunch['mealtime']=1

        bmi_lunch= predictBMI(df_lunch,'knn')[0]

        #------------------------------------------------------------
        jsonDinner = json.loads(calculate_ingredient(healthData.dinner))

        df_dinner = pd.json_normalize(jsonDinner)
        df_dinner['pa'] = pa
        df_dinner['age_x'] = healthData.age
        df_dinner['mealtime']=1

        bmi_dinner= predictBMI(df_dinner,'knn')[0]
        
        if (pa < 500 and bmi_actual >= 24.9):
            physical_activity_advice = physicalActivity(pa,500,paData[0].METs,healthData.minofexercise,healthData.noofexerciseaweek,healthData.activity)
        elif (pa < 1000 and pa >= 500 and bmi_actual >= 24.9):
            physical_activity_advice = physicalActivity(pa,500,paData[0].METs,healthData.minofexercise,healthData.noofexerciseaweek,healthData.activity)
        elif (bmi_actual < 24.9):
            physical_activity_advice = 'Please increase your exercise activity for a healthier you'
        else:
            physical_activity_advice = 'Please increase your exercise activity to reduce your health risk'

        
        if (bmi_breakfast >= 24.9):
            b_meal_advice = 'Please get healthier breakfast'
        if (bmi_lunch >= 24.9):
            l_meal_advice = 'Please get healthier lunch'
        if (bmi_dinner >= 24.9):
            d_meal_advice = 'Please get healthier dinner'            
        
        
            
        print(bmi_actual)
        print(bmi_breakfast)
        print(bmi_lunch)
        print(bmi_dinner)
    
    except Exception as e: 
        print(e)        
        print('Ooopss')
    
    response = Response()
    response.breakfastMealAdvice = b_meal_advice
    response.lunchMealAdvice = l_meal_advice
    response.dinnerMealAdvice = d_meal_advice
    response.physicalExerciseAdvice = physical_activity_advice
    
    jsonStr = json.dumps(response.__dict__)
    return jsonStr
    
         

class Response:
    breakfastMealAdvice = ''
    lunchMealAdvice = ''
    dinnerMealAdvice = ''
    physicalExerciseAdvice = ''

     

testdata = '{\
    "age":33,\
    "height": 168,\
    "weight": 76,\
    "activity": "conditioning exercise",\
    "motion": "stretching, mild",\
    "noofexerciseaweek":5,\
    "minofexercise":30,\
    "breakfast":"172791998",\
    "lunch":"5234",\
    "dinner":"58160110"}'
predictHealthRisk(testdata)
# Out:
# /Users/santi/Documents/Documents/Study/IRS Project/MyHealthApp/db/healthdb.db
# /Users/santi/Documents/Documents/Study/IRS Project/MyHealthApp/db/healthdb.db
# /Users/santi/Documents/Documents/Study/IRS Project/MyHealthApp/db/healthdb.db
# 1. Query task by recipe description:
# /Users/santi/Documents/Documents/Study/IRS Project/MyHealthApp/model/decision_tree_classifier.pkl
# /Users/santi/Documents/Documents/Study/IRS Project/MyHealthApp/model/knn_classifier.pkl
# /Users/santi/Documents/Documents/Study/IRS Project/MyHealthApp/db/healthdb.db
# /Users/santi/Documents/Documents/Study/IRS Project/MyHealthApp/db/healthdb.db
# 1. Query task by recipe description:
# /Users/santi/Documents/Documents/Study/IRS Project/MyHealthApp/model/decision_tree_classifier.pkl
# /Users/santi/Documents/Documents/Study/IRS Project/MyHealthApp/model/knn_classifier.pkl
# /Users/santi/Documents/Documents/Study/IRS Project/MyHealthApp/db/healthdb.db
# /Users/santi/Documents/Documents/Study/IRS Project/MyHealthApp/db/healthdb.db
# 1. Query task by recipe description:
# /Users/santi/Documents/Documents/Study/IRS Project/MyHealthApp/model/decision_tree_classifier.pkl
# /Users/santi/Documents/Documents/Study/IRS Project/MyHealthApp/model/knn_classifier.pkl
# /Users/santi/Documents/Documents/Study/IRS Project/MyHealthApp/db/healthdb.db
# /Users/santi/Documents/Documents/Study/IRS Project/MyHealthApp/db/healthdb.db
# 1. Specific Motion and Met by Activity:
# [{'SPECIFICMOTION': 'activity promoting video game (e.g., Wii Fit), light effort (e.g., balance, yoga)', 'METs': 2.3}, {'SPECIFICMOTION': 'activity promoting video game (e.g., Wii Fit), moderate effort (e.g., aerobic, resistance)', 'METs': 3.8}, {'SPECIFICMOTION': 'activity promoting video/arcade game (e.g., Exergaming, Dance Dance Revolution), vigorous effort', 'METs': 7.2}, {'SPECIFICMOTION': 'army type obstacle course exercise, boot camp training program', 'METs': 5.0}, {'SPECIFICMOTION': 'bicycling, stationary, general', 'METs': 7.0}, {'SPECIFICMOTION': 'bicycling, stationary, 30-50 watts, very light to light effort', 'METs': 3.5}, {'SPECIFICMOTION': 'bicycling, stationary, 90-100 watts, moderate to vigorous effort', 'METs': 6.8}, {'SPECIFICMOTION': 'bicycling, stationary, 101-160 watts, vigorous effort', 'METs': 8.8}, {'SPECIFICMOTION': 'bicycling, stationary, 161-200 watts, vigorous effort', 'METs': 11.0}, {'SPECIFICMOTION': 'bicycling, stationary, 201-270 watts, very vigorous effort', 'METs': 14.0}, {'SPECIFICMOTION': 'bicycling, stationary, 51-89 watts, light-to-moderate effort', 'METs': 4.8}, {'SPECIFICMOTION': 'bicycling, stationary, RPM/Spin bike class', 'METs': 8.5}, {'SPECIFICMOTION': 'calisthenics (e.g., push ups, sit ups, pull-ups, jumping jacks), vigorous effort', 'METs': 8.0}, {'SPECIFICMOTION': 'calisthenics (e.g., push ups, sit ups, pull-ups, lunges), moderate effort', 'METs': 3.8}, {'SPECIFICMOTION': 'calisthenics (e.g., situps, abdominal crunches), light effort', 'METs': 2.8}, {'SPECIFICMOTION': 'calisthenics, light or moderate effort, general (e.g., back exercises), going up & down from floor ( 150)', 'METs': 3.5}, {'SPECIFICMOTION': 'circuit training, moderate effort', 'METs': 4.3}, {'SPECIFICMOTION': 'circuit training, including kettlebells, some aerobic movement with minimal rest, general, vigorous intensity', 'METs': 8.0}, {'SPECIFICMOTION': 'CurvesTM\xa0exercise routines in women', 'METs': 3.5}, {'SPECIFICMOTION': 'Elliptical trainer, moderate effort', 'METs': 5.0}, {'SPECIFICMOTION': 'resistance training (weight lifting, free weight, nautilus or universal), power lifting or body building, vigorous effort', 'METs': 6.0}, {'SPECIFICMOTION': 'resistance (weight) training, squats , slow or explosive effort', 'METs': 5.0}, {'SPECIFICMOTION': 'resistance (weight) training, multiple exercises, 8-15 repetitions at varied resistance', 'METs': 3.5}, {'SPECIFICMOTION': 'health club exercise, general', 'METs': 5.5}, {'SPECIFICMOTION': 'health club exercise classes, general, gym/weight training combined in one visit', 'METs': 5.0}, {'SPECIFICMOTION': 'health club exercise, conditioning classes', 'METs': 7.8}, {'SPECIFICMOTION': 'home exercise, general', 'METs': 3.8}, {'SPECIFICMOTION': 'stair-treadmill ergometer, general', 'METs': 9.0}, {'SPECIFICMOTION': 'rope skipping, general', 'METs': 12.3}, {'SPECIFICMOTION': 'rowing, stationary ergometer, general, vigorous effort', 'METs': 6.0}, {'SPECIFICMOTION': 'rowing, stationary, general, moderate effort', 'METs': 4.8}, {'SPECIFICMOTION': 'rowing, stationary, 100 watts, moderate effort', 'METs': 7.0}, {'SPECIFICMOTION': 'rowing, stationary, 150 watts, vigorous effort', 'METs': 8.5}, {'SPECIFICMOTION': 'rowing, stationary, 200 watts, very vigorous effort', 'METs': 12.0}, {'SPECIFICMOTION': 'ski machine, general', 'METs': 6.8}, {'SPECIFICMOTION': 'slide board exercise, general', 'METs': 11.0}, {'SPECIFICMOTION': 'slimnastics, jazzercise', 'METs': 6.0}, {'SPECIFICMOTION': 'stretching, mild', 'METs': 2.3}, {'SPECIFICMOTION': 'pilates, general', 'METs': 3.0}, {'SPECIFICMOTION': 'teaching exercise class (e.g., aerobic, water)', 'METs': 6.8}, {'SPECIFICMOTION': 'therapeutic exercise ball, Fitball exercise', 'METs': 2.8}, {'SPECIFICMOTION': 'upper body exercise, arm ergometer', 'METs': 2.8}, {'SPECIFICMOTION': 'upper body exercise, stationary bicycle – Airdyne (arms only) 40 rpm, moderate', 'METs': 4.3}, {'SPECIFICMOTION': 'water aerobics, water calisthenics, water exercise', ...
# [{"specificmotion": "activity promoting video game (e.g., Wii Fit), light effort (e.g., balance, yoga)", "met": 2.3, "activity": "conditioning exercise"}, {"specificmotion": "activity promoting video game (e.g., Wii Fit), moderate effort (e.g., aerobic, resistance)", "met": 3.8, "activity": "conditioning exercise"}, {"specificmotion": "activity promoting video/arcade game (e.g., Exergaming, Dance Dance Revolution), vigorous effort", "met": 7.2, "activity": "conditioning exercise"}, {"specificmotion": "army type obstacle course exercise, boot camp training program", "met": 5.0, "activity": "conditioning exercise"}, {"specificmotion": "bicycling, stationary, general", "met": 7.0, "activity": "conditioning exercise"}, {"specificmotion": "bicycling, stationary, 30-50 watts, very light to light effort", "met": 3.5, "activity": "conditioning exercise"}, {"specificmotion": "bicycling, stationary, 90-100 watts, moderate to vigorous effort", "met": 6.8, "activity": "conditioning exercise"}, {"specificmotion": "bicycling, stationary, 101-160 watts, vigorous effort", "met": 8.8, "activity": "conditioning exercise"}, {"specificmotion": "bicycling, stationary, 161-200 watts, vigorous effort", "met": 11.0, "activity": "conditioning exercise"}, {"specificmotion": "bicycling, stationary, 201-270 watts, very vigorous effort", "met": 14.0, "activity": "conditioning exercise"}, {"specificmotion": "bicycling, stationary, 51-89 watts, light-to-moderate effort", "met": 4.8, "activity": "conditioning exercise"}, {"specificmotion": "bicycling, stationary, RPM/Spin bike class", "met": 8.5, "activity": "conditioning exercise"}, {"specificmotion": "calisthenics (e.g., push ups, sit ups, pull-ups, jumping jacks), vigorous effort", "met": 8.0, "activity": "conditioning exercise"}, {"specificmotion": "calisthenics (e.g., push ups, sit ups, pull-ups, lunges), moderate effort", "met": 3.8, "activity": "conditioning exercise"}, {"specificmotion": "calisthenics (e.g., situps, abdominal crunches), light effort", "met": 2.8, "activity": "conditioning exercise"}, {"specificmotion": "calisthenics, light or moderate effort, general (e.g., back exercises), going up & down from floor ( 150)", "met": 3.5, "activity": "conditioning exercise"}, {"specificmotion": "circuit training, moderate effort", "met": 4.3, "activity": "conditioning exercise"}, {"specificmotion": "circuit training, including kettlebells, some aerobic movement with minimal rest, general, vigorous intensity", "met": 8.0, "activity": "conditioning exercise"}, {"specificmotion": "CurvesTM\u00a0exercise routines in women", "met": 3.5, "activity": "conditioning exercise"}, {"specificmotion": "Elliptical trainer, moderate effort", "met": 5.0, "activity": "conditioning exercise"}, {"specificmotion": "resistance training (weight lifting, free weight, nautilus or universal), power lifting or body building, vigorous effort", "met": 6.0, "activity": "conditioning exercise"}, {"specificmotion": "resistance (weight) training, squats , slow or explosive effort", "met": 5.0, "activity": "conditioning exercise"}, {"specificmotion": "resistance (weight) training, multiple exercises, 8-15 repetitions at varied resistance", "met": 3.5, "activity": "conditioning exercise"}, {"specificmotion": "health club exercise, general", "met": 5.5, "activity": "conditioning exercise"}, {"specificmotion": "health club exercise classes, general, gym/weight training combined in one visit", "met": 5.0, "activity": "conditioning exercise"}, {"specificmotion": "health club exercise, conditioning classes", "met": 7.8, "activity": "conditioning exercise"}, {"specificmotion": "home exercise, general", "met": 3.8, "activity": "conditioning exercise"}, {"specificmotion": "stair-treadmill ergometer, general", "met": 9.0, "activity": "conditioning exercise"}, {"specificmotion": "rope skipping, general", "met": 12.3, "activity": "conditioning exercise"}, {"specificmotion": "rowing, stationary ergometer, general, vigorous effort", "met": 6.0, "ac ...
# 26.92743764172336
# 31.0
# 31.0
# 26.0
# '{"breakfastMealAdvice": "Please get healthier breakfast", "lunchMealAdvice": "Please get healthier lunch", "dinnerMealAdvice": "Please get healthier dinner", "physicalExerciseAdvice": "Please increase your exercise time to 30 minutes and try to do activity promoting video game (e.g., Wii Fit), moderate effort (e.g., aerobic, resistance)"}'
